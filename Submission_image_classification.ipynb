# %% [markdown]
# # Proyek Klasifikasi Gambar: PlantVillage Dataset
# - **Nama:** M Wildan Nurohman
# - **Email:** wildangtg15@gmail.com
# - **ID Dicoding:** wildannurohman

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.22.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: flax>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.10.6)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (6.5.2)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.2)
# Requirement already satisfied: jaxlib>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.1)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tf-keras>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.11.0)
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.16.1)
# Collecting packaging~=23.1 (from tensorflowjs)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (2.0.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.11.13)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.74)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (4.13.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.9)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (1.15.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.11.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.19.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.89)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (1.12.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.12.3)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2025.3.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.21.0)
# Downloading tensorflowjs-4.22.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 4.2 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: packaging, tensorflowjs
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 3.31.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# Successfully installed packaging-23.2 tensorflowjs-4.22.0

# %%
# cek versi TensorFlow
import tensorflow as tf
print("TensorFlow version:", tf.__version__)

# cek versi Keras
print("Keras version:", tf.keras.__version__)
# Out:
# TensorFlow version: 2.18.0
# Keras version: 3.8.0

# %%
import os
import random
import shutil
import pathlib

# PIL untuk image processing
from PIL import Image

# matplotlib untuk plotting
import matplotlib.pyplot as plt

# import library TensorFlow dan Keras
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetV2B0, MobileNetV2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Accuracy, Precision, Recall
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image

import array as np
from google.colab import drive
import zipfile
from collections import defaultdict
import subprocess

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data Loading

# %% [markdown]
# dataset didapat dari kaggle, namun untuk mempercepat proses ekstrak saya upload dataset zip tersebut ke gdrive pribadi

# %%
# mount gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ekstrak file
import zipfile

zip_path = '/content/drive/MyDrive/datasetplantv.zip'
extract_path = '/content/datasetplantvillage'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
def summarize_dataset(directory_path, focus_resolution=None):
    image_per_class = {}
    resolution_stats = defaultdict(int)
    matched_target_res = 0

    for root, dirs, files in os.walk(directory_path):
        if root == directory_path:
            continue  # lewati folder utama

        class_label = os.path.basename(root)
        valid_images = 0

        for fname in files:
            fpath = os.path.join(root, fname)
            try:
                with Image.open(fpath) as img:
                    w, h = img.size
                    key = f"{w}x{h}"
                    resolution_stats[key] += 1
                    valid_images += 1

                    if focus_resolution and key == focus_resolution:
                        matched_target_res += 1
            except Exception:
                continue  # lewati file yang gagal dibuka sebagai gambar

        image_per_class[class_label] = valid_images

    if focus_resolution:
        resolution_stats["matched_target"] = matched_target_res

    return image_per_class, dict(resolution_stats)

# menyesuaikan path dataset
dataset_path = "/content/datasetplantvillage"
wanted_resolution = "256x256"

classes, resolutions = summarize_dataset(dataset_path, wanted_resolution)

print(" Jumlah gambar per kelas:")
for cls, total in classes.items():
    print(f"  {cls}: {total}")

print ("===============================================")

print("\n Statistik resolusi gambar:")
for res, total in resolutions.items():
    label = " (target)" if res == "matched_target" else ""
    print(f"  {res}: {total}{label}")
# Out:
#  Jumlah gambar per kelas:
#   PlantVillage: 0
#   Tomato_Early_blight: 1000
#   Pepper__bell___healthy: 1478
#   Potato___Late_blight: 1000
#   Pepper__bell___Bacterial_spot: 997
#   Potato___healthy: 152
#   Tomato__Target_Spot: 1404
#   Tomato__Tomato_mosaic_virus: 373
#   Tomato_Spider_mites_Two_spotted_spider_mite: 1676
#   Tomato_Leaf_Mold: 952
#   Tomato_Bacterial_spot: 2127
#   Tomato_Late_blight: 1909
#   Tomato_healthy: 1591
#   Potato___Early_blight: 1000
#   Tomato__Tomato_YellowLeaf__Curl_Virus: 3208
#   Tomato_Septoria_leaf_spot: 1771
#   plantvillage: 0
# ===============================================
#
#  Statistik resolusi gambar:
#   256x256: 41276
#   matched_target: 41276 (target)

# %%
def random_resize_images(target_dir, size_range=(200, 256)):
    image_count = 0
    for subdir, _, files in os.walk(target_dir):
        for filename in files:
            img_path = os.path.join(subdir, filename)
            try:
                with Image.open(img_path) as im:
                    # menentukan ukuran baru secara acak
                    width = random.choice(range(size_range[0], size_range[1] + 1))
                    height = random.choice(range(size_range[0], size_range[1] + 1))

                    resized = im.resize((width, height), resample=Image.LANCZOS)
                    resized.save(img_path)
                    image_count += 1
            except Exception as e:
                print(f"Skip {img_path}: {e}")

    print(f"✔️ Selesai resize {image_count} gambar di: {target_dir}")

# menjalankan fungsi dengan path dataset PlantVillage
dataset_path = "/content/datasetplantvillage"
random_resize_images(dataset_path)
# Out:
# Skip /content/datasetplantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/svn-r6Yb5c: cannot identify image file '/content/datasetplantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/svn-r6Yb5c'
# Skip /content/datasetplantvillage/plantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/svn-r6Yb5c: cannot identify image file '/content/datasetplantvillage/plantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus/svn-r6Yb5c'
# ✔️ Selesai resize 41276 gambar di: /content/datasetplantvillage

# %%
def analyze_dataset(dataset_path, expected_res=None):
    per_class_count = {}
    resolution_count = defaultdict(int)
    matched_res_count = 0
    total_images = 0

    for subdir, _, files in os.walk(dataset_path):
        if subdir == dataset_path:
            continue  # lewati folder root utama

        class_label = os.path.basename(subdir)
        class_image_count = 0

        for file_name in files:
            img_path = os.path.join(subdir, file_name)
            try:
                with Image.open(img_path) as img:
                    w, h = img.size
                    res_label = f"{w}x{h}"
                    resolution_count[res_label] += 1
                    class_image_count += 1
                    total_images += 1

                    if expected_res and res_label == expected_res:
                        matched_res_count += 1

            except Exception:
                continue  # lewati file rusak atau bukan gambar

        per_class_count[class_label] = class_image_count

    return per_class_count, dict(resolution_count), matched_res_count, total_images

#
dataset_path = "/content/datasetplantvillage"
target_size = "256x256"

classes, resolutions, matched, total = analyze_dataset(dataset_path, target_size)

print(f" Total gambar valid: {total}")
print("\n Jumlah gambar per kelas:")
for cls, count in classes.items():
    print(f"  {cls}: {count}")

print("\n🖼️ Jumlah gambar per resolusi:")
for res, count in resolutions.items():
    print(f"  {res}: {count}")
# Out:
#  Total gambar valid: 41276
#
#  Jumlah gambar per kelas:
#   PlantVillage: 0
#   Tomato_Early_blight: 1000
#   209x215: 9
#   255x247: 7
#   237x256: 8
#   218x208: 12
#   216x226: 13
#   248x245: 9
#   223x225: 14
#   231x242: 7
#   201x222: 9
#   233x202: 8
#   207x222: 17
#   212x215: 10
#   254x210: 5
#   215x240: 8
#   243x210: 11
#   242x209: 8
#   256x240: 14
#   232x242: 15
#   254x236: 10
#   245x200: 6
#   244x227: 6
#   218x203: 8
#   229x245: 6
#   236x232: 12
#   206x251: 9
#   206x253: 8
#   206x233: 7
#   210x227: 14
#   231x208: 10
#   201x221: 13
#   234x225: 8
#   253x234: 10
#   243x208: 7
#   236x202: 7
#   213x205: 15
#   249x207: 5
#   246x215: 12
#   247x254: 8
#   236x215: 9
#   220x244: 13
#   250x238: 9
#   240x200: 10
#   251x242: 12
#   223x227: 15
#   207x244: 8
#   214x232: 12
#   206x209: 7
#   221x200: 10
#   251x229: 8
#   231x237: 9
#   211x213: 13
#   207x217: 8
#   247x208: 7
#   247x216: 10
#   243x237: 7
#   201x208: 9
#   228x241: 9
#   221x232: 9
#   245x221: 10
#   244x247: 4
#   254x254: 6
#   239x209: 7

# %%
print(f"\n Jumlah gambar dengan resolusi target ({target_size}): {matched}")
# Out:
#  Jumlah gambar dengan resolusi target (256x256): 14

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Split Dataset

# %%
def summarize_images(dataset_path, focus_class="potato"):
    total_images = 0
    focused_class_images = 0

    for current_dir, _, image_files in os.walk(dataset_path):
        total_images += len(image_files)

        # cek apakah direktori saat ini mengandung kelas target
        if focus_class.lower() in current_dir.lower():
            focused_class_images += len(image_files)

    return total_images, focused_class_images

# ganti ini dengan lokasi folder utama dataset kamu
path_to_dataset = "/content/datasetplantvillage"
class_to_check = "tomato"

# jalankan fungsi
all_images, class_images = summarize_images(path_to_dataset, focus_class=class_to_check)

# cetak hasilnya
print(f" Total images found           : {all_images}")
print(f" Images in class '{class_to_check}' : {class_images}")
# Out:
#  Total images found           : 41278
#  Images in class 'tomato' : 32024

# %%
def summarize_subclass_counts(dataset_path, focus_class="tomato"):
    subclass_summary = {}

    for current_dir, _, files in os.walk(dataset_path):
        # hanya proses folder yang relevan dengan kelas target
        if focus_class.lower() in current_dir.lower():
            subclass = os.path.basename(current_dir)
            subclass_summary[subclass] = subclass_summary.get(subclass, 0) + len(files)

    return subclass_summary

# tentukan lokasi dataset dan kelas yang ingin dianalisis
dataset_path = "/content/datasetplantvillage"
target_class = "tomato"  # Ganti dengan 'potato' atau lainnya jika perlu

# hitung total gambar per subkelas
summary = summarize_subclass_counts(dataset_path, focus_class=target_class)

# tampilkan hasil
print(f"\n Distribusi subkelas gambar untuk '{target_class}' :\n")
for subclass_name, image_count in summary.items():
    print(f"  • {subclass_name:<30} : {image_count} images")
# Out:
#  Distribusi subkelas gambar untuk 'tomato' :
#
#   • Tomato_Early_blight            : 2000 images
#   • Tomato__Target_Spot            : 2808 images
#   • Tomato__Tomato_mosaic_virus    : 746 images
#   • Tomato_Spider_mites_Two_spotted_spider_mite : 3352 images
#   • Tomato_Leaf_Mold               : 1904 images
#   • Tomato_Bacterial_spot          : 4254 images
#   • Tomato_Late_blight             : 3818 images
#   • Tomato_healthy                 : 3182 images
#   • Tomato__Tomato_YellowLeaf__Curl_Virus : 6418 images
#   • Tomato_Septoria_leaf_spot      : 3542 images

# %%
def copy_tomato_folders(dataset_path, target_folder="dataset", target_class="tomato"):
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    for root, dirs, files in os.walk(dataset_path):
        for dir_name in dirs:
            if target_class.lower() in dir_name.lower():
                source_path = os.path.join(root, dir_name)
                dest_path = os.path.join(target_folder, dir_name)
                if not os.path.exists(dest_path):
                    shutil.copytree(source_path, dest_path)
                    print(f"Menyalin {source_path} ke {dest_path}")

# sesuaikan path folder utama
dataset_path = "/content/datasetplantvillage"

# ke folder tujuan
target_folder = "/content/dataset-tomato"

copy_tomato_folders(dataset_path, target_folder)
# Out:
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato_Early_blight ke /content/dataset-tomato/Tomato_Early_blight
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato__Target_Spot ke /content/dataset-tomato/Tomato__Target_Spot
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato__Tomato_mosaic_virus ke /content/dataset-tomato/Tomato__Tomato_mosaic_virus
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato_Spider_mites_Two_spotted_spider_mite ke /content/dataset-tomato/Tomato_Spider_mites_Two_spotted_spider_mite
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato_Leaf_Mold ke /content/dataset-tomato/Tomato_Leaf_Mold
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato_Bacterial_spot ke /content/dataset-tomato/Tomato_Bacterial_spot
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato_Late_blight ke /content/dataset-tomato/Tomato_Late_blight
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato_healthy ke /content/dataset-tomato/Tomato_healthy
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato__Tomato_YellowLeaf__Curl_Virus ke /content/dataset-tomato/Tomato__Tomato_YellowLeaf__Curl_Virus
# Menyalin /content/datasetplantvillage/PlantVillage/Tomato_Septoria_leaf_spot ke /content/dataset-tomato/Tomato_Septoria_leaf_spot

# %%
def clean_folder_names(root_path, prefix_to_remove="Tomato___"):
    """
    Menghapus prefix Tomato___ dalam direktori.
    """
    for current_dir, subdirs, _ in os.walk(root_path):
        for subdir in subdirs:
            if subdir.startswith(prefix_to_remove):
                trimmed_name = subdir[len(prefix_to_remove):]
                original_path = os.path.join(current_dir, subdir)
                updated_path = os.path.join(current_dir, trimmed_name)

                os.rename(original_path, updated_path)
                print(f"Folder renamed: {original_path} → {updated_path}")

# sesuaikan dengan path
dataset_path = "/content/dataset-tomato"

# Run the renaming process
clean_folder_names(dataset_path)

# %%
def show_sample_images(dataset_path):
    """
    menampilkan salah satu gambar random dari setiap kelas.
    """
    sample_images = {}

    for root, _, files in os.walk(dataset_path):
        if files:
            class_name = os.path.basename(root)
            chosen_image = random.choice(files)
            sample_images[class_name] = os.path.join(root, chosen_image)

    num_classes = len(sample_images)
    fig, axes = plt.subplots(1, num_classes, figsize=(4 * num_classes, 5))
    fig.suptitle("Sample Random untuk setiap kelas", fontsize=14)

    # jika hanya satu subplot, jadikan list agar bisa di-iterasi
    if num_classes == 1:
        axes = [axes]

    # menampilkan setiap gambar dengan label kelasnya
    for ax, (class_name, image_path) in zip(axes, sample_images.items()):
        image = Image.open(image_path)
        ax.imshow(image)
        ax.set_title(class_name, fontsize=10)
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# sesuaikan dataset
dataset_path = "/content/dataset-tomato"
show_sample_images(dataset_path)

# %% [markdown]
# **SPLIT DATASET**
#
# minimal dataset yg dibutuhkan adalah 10.000, jadi akan dipilih 5 kelas saja

# %%
def delete_unwanted_folders(dataset_path, keep_folders=['Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato_Bacterial_spot','Tomato_healthy','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato_Septoria_leaf_spot']):
    for item in os.listdir(dataset_path):
        item_path = os.path.join(dataset_path, item)
        if os.path.isdir(item_path) and item not in keep_folders:
            shutil.rmtree(item_path)
            print(f"Menghapus folder: {item_path}")

# sesuaikan path folder
dataset_path = "/content/dataset-tomato"

delete_unwanted_folders(dataset_path)
# Out:
# Menghapus folder: /content/dataset-tomato/Tomato_Early_blight
# Menghapus folder: /content/dataset-tomato/Tomato__Target_Spot
# Menghapus folder: /content/dataset-tomato/Tomato__Tomato_mosaic_virus
# Menghapus folder: /content/dataset-tomato/Tomato_Leaf_Mold
# Menghapus folder: /content/dataset-tomato/Tomato_Late_blight

# %%
# membagi dataset dengan rasio 80:20

def split_dataset(dataset_path, train_ratio=0.8):
    # path untuk dataset training dan testing
    train_path = os.path.join(dataset_path, 'train')
    test_path = os.path.join(dataset_path, 'test')

    # membuat folder train dan test
    os.makedirs(train_path, exist_ok=True)
    os.makedirs(test_path, exist_ok=True)

    for root, dirs, files in os.walk(dataset_path):
        if root == dataset_path:
            continue

        class_name = os.path.basename(root)
        if class_name in ['train', 'test']:
            continue

        # membuat folder kelas di dalam train dan test
        train_class_path = os.path.join(train_path, class_name)
        test_class_path = os.path.join(test_path, class_name)
        os.makedirs(train_class_path, exist_ok=True)
        os.makedirs(test_class_path, exist_ok=True)

        # shuffle files
        random.shuffle(files)
        split_index = int(train_ratio * len(files))
        train_files = files[:split_index]
        test_files = files[split_index:]

        # memindahkan file ke folder train
        for file in train_files:
            src_file = os.path.join(root, file)
            dst_file = os.path.join(train_class_path, file)
            shutil.move(src_file, dst_file)

        # memindahkan file ke folder test
        for file in test_files:
            src_file = os.path.join(root, file)
            dst_file = os.path.join(test_class_path, file)
            shutil.move(src_file, dst_file)

# path ke folder utama
dataset_path = "/content/dataset-tomato"

split_dataset(dataset_path)

# %%
def delete_directory_unwanted(dataset_path, keep_folders=['train', 'test']):
    for item in os.listdir(dataset_path):
        item_path = os.path.join(dataset_path, item)
        if os.path.isdir(item_path) and item not in keep_folders:
            shutil.rmtree(item_path)
            print(f"Menghapus folder: {item_path}")

# sesuaikan path folder
dataset_path = "/content/dataset-tomato"

delete_directory_unwanted(dataset_path)
# Out:
# Menghapus folder: /content/dataset-tomato/Tomato_Spider_mites_Two_spotted_spider_mite
# Menghapus folder: /content/dataset-tomato/Tomato_Bacterial_spot
# Menghapus folder: /content/dataset-tomato/Tomato_healthy
# Menghapus folder: /content/dataset-tomato/Tomato__Tomato_YellowLeaf__Curl_Virus
# Menghapus folder: /content/dataset-tomato/Tomato_Septoria_leaf_spot

# %% [markdown]
# ## Modelling

# %%
def prepare_image_generator(dataset_path, img_size=(130, 130), batch_size=32):
    train_path = os.path.join(dataset_path, 'train')
    test_path = os.path.join(dataset_path, 'test')

    train_datagen = ImageDataGenerator(
        rescale=1./255,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest'
    )

    # rescale untuk data test
    datagen_test = ImageDataGenerator(rescale=1./255)


    train_generator = train_datagen.flow_from_directory(
        train_path,
        target_size=img_size,
        batch_size=batch_size,
        class_mode='categorical'
    )

    test_generator = datagen_test.flow_from_directory(
        test_path,
        target_size=img_size,
        batch_size=batch_size,
        class_mode='categorical'
    )

    return train_generator, test_generator

# sesuaikan path
dataset_path = "/content/dataset-tomato"

train_generator, test_generator = prepare_image_generator(dataset_path)

# cek kelas yg ada di dataset
class_indices = train_generator.class_indices
print(class_indices)
# Out:
# Found 8295 images belonging to 5 classes.
# Found 2078 images belonging to 5 classes.
# {'Tomato_Bacterial_spot': 0, 'Tomato_Septoria_leaf_spot': 1, 'Tomato_Spider_mites_Two_spotted_spider_mite': 2, 'Tomato__Tomato_YellowLeaf__Curl_Virus': 3, 'Tomato_healthy': 4}

# %%
# menggunakan transfer learning dan MobileNetV2

pretrained_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(150,150,3))

for layer in pretrained_model.layers:
    layer.trainable = False

model = Sequential()

model.add(pretrained_model)

# menambahkan Conv2D and Pooling layers
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten(name="flatten"))
model.add(Dropout(0.5))
model.add(Dense(128, activation="relu"))
model.add(Dense(4, activation='softmax'))
# Out:
# <ipython-input-21-f85bfe66c752>:3: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   pretrained_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(150,150,3))
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# menggunakan transfer learning based on MobileNetV2

def create_tomato_disease_classifier(input_dimensions=(130, 130, 3), num_classes=5):

   # load pre-trained MobileNetV2
   base_network = MobileNetV2(
       weights="imagenet",
       include_top=False,
       input_shape=input_dimensions
   )

   # freeze model layer supaya tidak perlu melatih ulang
   for layer in base_network.layers:
       layer.trainable = False

   classifier = Sequential(name="TomatoDiseaseClassifier")

   # tambahkan jaringan dasar
   classifier.add(base_network)

   # tambahkan kustom layer untuk feature extraction dan klasifikasi
   classifier.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
   classifier.add(MaxPooling2D(pool_size=(2, 2)))
   classifier.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
   classifier.add(MaxPooling2D(pool_size=(2, 2)))

   # ratakan dan tambah layer yg terhubung sepenuhnya
   classifier.add(Flatten(name="flatten_features"))
   classifier.add(Dropout(rate=0.5))
   classifier.add(Dense(128, activation="relu"))
   classifier.add(Dense(num_classes, activation='softmax'))

   return classifier

# buat model
tomato_classifier = create_tomato_disease_classifier()
# Out:
# <ipython-input-22-e35c1ae2cfe1>:6: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_network = MobileNetV2(

# %% [markdown]
# **COMPILE MODEL**

# %%
# melakukan kompilasi model dengan optimizer Adam, loss categorical cross-entropy, dan metrik evaluasi.

def compile_model(model, learning_rate=0.001):

    # inisialisasi optimizer Adam dengan learning rate yang ditentukan
    optimizer = Adam(learning_rate=learning_rate)

    # compile model dengan konfigurasi yang diinginkan
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy', Precision(), Recall()]
    )

    return model

# compile model yang telah dibuat sebelumnya
tomato_classifier = compile_model(tomato_classifier)

# tampilkan ringkasan model
tomato_classifier.summary()
# Out:
# Model: "TomatoDiseaseClassifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 5, 5, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 5, 5, 32)       │       368,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 2, 2, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_features (Flatten)      │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,654,117 (10.12 MB)
#  Trainable params: 396,133 (1.51 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# membuat callback early stopping yg memonitor val_accuracy

earlystop_cb = EarlyStopping(
    monitor="val_accuracy",
    patience=5,                   # berhenti jika tidak ada peningkatan dalam 5 epoch
    restore_best_weights=True,
    mode="max",
    verbose=1
)

# %%
# membuat callback model checkpoint yg memonitor val_accuracy
checkpoint_cb = ModelCheckpoint(
    "best_model.h5",
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)

# %%
# training model
num_epochs = 15

W = tomato_classifier.fit(train_generator,
              epochs=num_epochs,
              validation_data=test_generator,
              callbacks=[earlystop_cb, checkpoint_cb],
              verbose=1)
# Out:
# Epoch 1/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9704 - loss: 0.0994 - precision: 0.9728 - recall: 0.9682
# Epoch 1: val_accuracy improved from 0.95621 to 0.96150, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 41s 159ms/step - accuracy: 0.9704 - loss: 0.0993 - precision: 0.9728 - recall: 0.9682 - val_accuracy: 0.9615 - val_loss: 0.1312 - val_precision: 0.9629 - val_recall: 0.9610
# Epoch 2/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9678 - loss: 0.0997 - precision: 0.9696 - recall: 0.9657
# Epoch 2: val_accuracy did not improve from 0.96150
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 82s 161ms/step - accuracy: 0.9678 - loss: 0.0996 - precision: 0.9696 - recall: 0.9657 - val_accuracy: 0.9355 - val_loss: 0.2181 - val_precision: 0.9390 - val_recall: 0.9341
# Epoch 3/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9724 - loss: 0.0909 - precision: 0.9744 - recall: 0.9692
# Epoch 3: val_accuracy did not improve from 0.96150
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 42s 161ms/step - accuracy: 0.9724 - loss: 0.0909 - precision: 0.9744 - recall: 0.9692 - val_accuracy: 0.9413 - val_loss: 0.2048 - val_precision: 0.9424 - val_recall: 0.9370
# Epoch 4/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9780 - loss: 0.0693 - precision: 0.9806 - recall: 0.9750
# Epoch 4: val_accuracy did not improve from 0.96150
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 41s 158ms/step - accuracy: 0.9780 - loss: 0.0693 - precision: 0.9806 - recall: 0.9751 - val_accuracy: 0.9355 - val_loss: 0.2079 - val_precision: 0.9399 - val_recall: 0.9336
# Epoch 5/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9709 - loss: 0.0956 - precision: 0.9736 - recall: 0.9669
# Epoch 5: val_accuracy improved from 0.96150 to 0.96968, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 42s 159ms/step - accuracy: 0.9709 - loss: 0.0956 - precision: 0.9736 - recall: 0.9669 - val_accuracy: 0.9697 - val_loss: 0.1038 - val_precision: 0.9739 - val_recall: 0.9687
# Epoch 6/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9741 - loss: 0.0776 - precision: 0.9754 - recall: 0.9710
# Epoch 6: val_accuracy did not improve from 0.96968
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 41s 155ms/step - accuracy: 0.9741 - loss: 0.0776 - precision: 0.9754 - recall: 0.9710 - val_accuracy: 0.9620 - val_loss: 0.1422 - val_precision: 0.9629 - val_recall: 0.9605
# Epoch 7/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9785 - loss: 0.0643 - precision: 0.9800 - recall: 0.9770
# Epoch 7: val_accuracy did not improve from 0.96968
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 40s 156ms/step - accuracy: 0.9785 - loss: 0.0644 - precision: 0.9800 - recall: 0.9769 - val_accuracy: 0.9629 - val_loss: 0.1579 - val_precision: 0.9633 - val_recall: 0.9605
# Epoch 8/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9794 - loss: 0.0681 - precision: 0.9808 - recall: 0.9771
# Epoch 8: val_accuracy did not improve from 0.96968
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 40s 155ms/step - accuracy: 0.9794 - loss: 0.0681 - precision: 0.9808 - recall: 0.9771 - val_accuracy: 0.9408 - val_loss: 0.2057 - val_precision: 0.9438 - val_recall: 0.9370
# Epoch 9/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9807 - loss: 0.0607 - precision: 0.9822 - recall: 0.9787
# Epoch 9: val_accuracy did not improve from 0.96968
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 42s 161ms/step - accuracy: 0.9807 - loss: 0.0607 - precision: 0.9822 - recall: 0.9787 - val_accuracy: 0.9413 - val_loss: 0.2189 - val_precision: 0.9448 - val_recall: 0.9389
# Epoch 10/15
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9774 - loss: 0.0736 - precision: 0.9789 - recall: 0.9758
# Epoch 10: val_accuracy did not improve from 0.96968
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 40s 155ms/step - accuracy: 0.9774 - loss: 0.0736 - precision: 0.9789 - recall: 0.9758 - val_accuracy: 0.9615 - val_loss: 0.1324 - val_precision: 0.9670 - val_recall: 0.9591
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %% [markdown]
# ## Evaluasi dan Visualisasi

# %%
def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 4))

    # Grafik Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'r', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Grafik Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# sesuaikan fungsi dengan history
plot_training_history(W)

# %% [markdown]
# ## Konversi Model

# %%
def save_all_formats(model, base_name='model_tomato'):
    # save ke .keras (native keras v3 format)
    keras_path = f'{base_name}.keras'
    model.save(keras_path)
    print(f'[✔] Saved as .keras -> {keras_path}')

    # save ke .h5
    h5_path = f'{base_name}.h5'
    model.save(h5_path)
    print(f' Saved as .h5 -> {h5_path}')

    # save ke SavedModel
    saved_model_dir = f'{base_name}_saved_model'
    model.export(saved_model_dir)
    print(f' Saved as SavedModel -> {saved_model_dir}/')

    # konversi ke TFLite
    tflite_path = f'{base_name}.tflite'
    converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
    tflite_model = converter.convert()
    with open(tflite_path, 'wb') as f:
        f.write(tflite_model)
    print(f'Saved as TFLite -> {tflite_path}')

    # konversi ke TensorFlow.js
    tfjs_dir = f'{base_name}_tfjs'
    try:
        subprocess.run([
            'tensorflowjs_converter',
            '--input_format=keras',
            h5_path,
            tfjs_dir
        ], check=True)
        print(f' Converted to TensorFlow.js -> {tfjs_dir}/')
    except Exception as e:
        print(' TFJS conversion failed. Make sure tensorflowjs is installed with: pip install tensorflowjs')
        print(W)

# %%
save_all_formats(model, base_name='tomato_classifier')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [✔] Saved as .keras -> tomato_classifier.keras
#  Saved as .h5 -> tomato_classifier.h5
# Saved artifact at 'tomato_classifier_saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   132139924479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924483600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924483216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924482064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923646096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924483024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924483984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924483792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924484368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924485904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924482640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924482832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924484944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139924487824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922785872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922784528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922784912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922784720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922787408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922787024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922786640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922787600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922786256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922789712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922790096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922790480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922790288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922785104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922791632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922792016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922792400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922792208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922788560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922793552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922793936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922794320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922794128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922789328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922791248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922796048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922796432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922796240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922792784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922795088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922798160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922798544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922798352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922795472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922798928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922800272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922797776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922795664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922799312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139922799696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923178896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923177936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923178704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923177744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923180432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923180816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923181200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923181008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923178128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923182352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923182736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923183120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923182928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923179280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923184272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923184656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923185040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923184848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923180048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923186192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923186576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923186960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923186768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923181968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923188112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923188496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923188880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923188688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923183888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923190032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923190416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923190800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923190608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923185808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923191952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923192336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923192720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923192528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923187728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923189648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923587536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923588112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923191568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923191184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923589072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923589456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923589840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923589648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923588304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923590992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923591376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923591760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923591568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923587728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923592912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923593296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923593680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923593488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923588688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923594832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923595216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923595600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923595408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923590608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923596752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923597136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923597520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923597328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923592528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923598672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923599056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923599440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923599248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923594448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923600592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923600976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923601360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923601168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923596368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923602512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923602128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923601744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923603088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923598288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139923600208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919787408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919787792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919787600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919786256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919788944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919789328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919789712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919789520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919786064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919790864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919791248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919791632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919791440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919787024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919792784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919793168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919793552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919793360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919788560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919794704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919795088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919795472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919795280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919790480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919796624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919797008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919797392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919797200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919792400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919798544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919798928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919799312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919799120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919794320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919800464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919800848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919801232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919801040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919796240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919798160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920212240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920213008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919800080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139919799696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920213968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920214352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920214736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920214544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920213200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920215888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920216272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920216656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920216464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920212048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920217808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920218192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920218576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920218384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920213584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920219728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920220112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920220496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920220304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920215504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920221648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920222032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920222416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920222224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920217424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920223568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920223952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920224336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920224144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920219344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920225488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920225872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920226064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920221264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920227408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920227024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920223184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139920225104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851203984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851203024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851203792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851202832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851205520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851205904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851206288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851206096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851203216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851207440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851207824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851208208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851208016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851204368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851209360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851209744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851210128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851209936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851205136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851211280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851211664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851212048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851211856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851207056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851213200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851213584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851213968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851213776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851208976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851215120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851215504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851215888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851215696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851210896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851203600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851218576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851218000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139851216656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139852021840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139852023760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139852023568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132139852024720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#  Saved as SavedModel -> tomato_classifier_saved_model/
# Saved as TFLite -> tomato_classifier.tflite
#  Converted to TensorFlow.js -> tomato_classifier_tfjs/

# %%
# !pip freeze > requirements.txt
